# %%
import os

destinationFolders=["D://Processing", "D://Queue", "D://Processed"]

for folder in destinationFolders:
    if not os.path.exists(folder):
        os.mkdir(folder)
        print("Directory " , folder ,  " Created ")
    else:    
        print("Directory " , folder ,  " already exists")
  
print(destinationFolders[0])
def test():
    print('Hello, World!')

def sched_job():
    schedule.every(1).seconds.do(test)
    return schedule.CancelJob

schedule.every().day.at('13:56').do(sched_job)

while True:
    schedule.run_pending()
    time.sleep(1)
    #here in test() you need to add file creating wala code
    
    f = open("demofile2.txt", "a")
f.write("Now the file has more content!")
f.close()
#but for the file name append increment value to get unique
 def filemovetoQueue:
    # file move to Queue folder 
def sched_job():
    schedule.every(1).seconds.do(test)
    schedule.every(5).seconds.do(filemovetoQueue)
    return schedule.CancelJob

schedule.every().day.at('13:56').do(sched_job)
 def filemovetoQueue:
    # file move to Queue folder 
    source=destinationFolders[0]
    destination=destinationFolders[1]
    allfiles = os.listdir(source)
 
    for f in allfiles:
        os.rename(source + f, destination + f)
        import mysql.connector

mydb = mysql.connector.connect(
  host="localhost",
  user="yourusername",
  password="yourpassword",
  database="mydatabase"
)

mycursor = mydb.cursor()

sql = "INSERT INTO customers (name, address) VALUES (%s, %s)"
val = ("John", "Highway 21")
mycursor.execute(sql, val)

mydb.commit()

print(mycursor.rowcount, "record inserted.")
 def filemovetoQueue:
    # file move to Queue folder 
    source=destinationFolders[0]
    destination=destinationFolders[1]
    allfiles = os.listdir(source)
 
    for f in allfiles:
    shutil.move(source + f, destination + f)
    
    
    # db connection logic
# move the file to processed filder
